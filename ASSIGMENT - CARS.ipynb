# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt

# %%
ab = pd.read_excel("C:\\Users\\asusm\\OneDrive\\Documents\\CARSDATA-2.xlsx")
ab
# Out:
#          County      City  Postal Code  Model Year   CARS NAME    Model  \
# 0       Suffolk   Suffolk      23435.0        2018       TESLA  MODEL 3
# 1        Yakima    Yakima      98908.0        2020       TESLA  MODEL 3
# 2        Yakima    Yakima      98908.0        2021        AUDI   E-TRON
# 3      Danville  Danville      24541.0        2019       TESLA  MODEL 3
# 4       Norfolk   Norfolk      23518.0        2014        FORD    C-MAX
# ...         ...       ...          ...         ...         ...      ...
# 9994      Clark     Camas      98607.0        2020       TESLA  MODEL 3
# 9995       King    Renton      98058.0        2014         BMW       I3
# 9996  Snohomish  Lynnwood      98037.0        2021       TESLA  MODEL 3
# 9997    Spokane   Spokane      99224.0        2022  VOLKSWAGEN     ID.4
# 9998       King   Seattle      98136.0        2012      TOYOTA     RAV4
#
#                        Electric Vehicle Type  Electric Range
# ...

# %%
ab.loc[5]
# Out:
# County                                         Thurston
# City                                            Olympia
# Postal Code                                     98502.0
# Model Year                                         2015
# CARS NAME                                        NISSAN
# Model                                              LEAF
# Electric Vehicle Type    Battery Electric Vehicle (BEV)
# Electric Range                                       84
# Name: 5, dtype: object

# %%
ab.dropna()
# Out:
#          County      City  Postal Code  Model Year   CARS NAME    Model  \
# 0       Suffolk   Suffolk      23435.0        2018       TESLA  MODEL 3
# 1        Yakima    Yakima      98908.0        2020       TESLA  MODEL 3
# 2        Yakima    Yakima      98908.0        2021        AUDI   E-TRON
# 3      Danville  Danville      24541.0        2019       TESLA  MODEL 3
# 4       Norfolk   Norfolk      23518.0        2014        FORD    C-MAX
# ...         ...       ...          ...         ...         ...      ...
# 9994      Clark     Camas      98607.0        2020       TESLA  MODEL 3
# 9995       King    Renton      98058.0        2014         BMW       I3
# 9996  Snohomish  Lynnwood      98037.0        2021       TESLA  MODEL 3
# 9997    Spokane   Spokane      99224.0        2022  VOLKSWAGEN     ID.4
# 9998       King   Seattle      98136.0        2012      TOYOTA     RAV4
#
#                        Electric Vehicle Type  Electric Range
# ...

# %%
bc = ab.head(10)
bc
# Out:
#       County      City  Postal Code  Model Year  CARS NAME    Model  \
# 0    Suffolk   Suffolk      23435.0        2018      TESLA  MODEL 3
# 1     Yakima    Yakima      98908.0        2020      TESLA  MODEL 3
# 2     Yakima    Yakima      98908.0        2021       AUDI   E-TRON
# 3   Danville  Danville      24541.0        2019      TESLA  MODEL 3
# 4    Norfolk   Norfolk      23518.0        2014       FORD    C-MAX
# 5   Thurston   Olympia      98502.0        2015     NISSAN     LEAF
# 6   Thurston    Tenino      98589.0        2013  CHEVROLET     VOLT
# 7  Snohomish   Bothell      98021.0        2016      TESLA  MODEL S
# 8       King   Seattle      98112.0        2018     NISSAN     LEAF
# 9   Kittitas  Cle Elum      98922.0        2018      TESLA  MODEL 3
#
#                     Electric Vehicle Type  Electric Range
# 0          Battery Electric Vehicle (BEV)             215
# 1          Battery Electric Vehicle (BEV)             308
# ...

# %%
plt.plot()
# Out:
# []
